# %%
item1 = "a"
item2 = "b"
item3 = "c"
item4 = "d"
item =  ["a","b","c", "d"]
item
# Out:
# ['a', 'b', 'c', 'd']

# %%
item[:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
item.append("e")
item
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
item.insert(0,"f")
item
# Out:
# ['f', 'a', 'b', 'c', 'd', 'e']

# %%
item1 = "a"
item2 = "b"
item3 = "c"
item4 = "d"
item =  ["a","b","c", "d"]
item
# Out:
# ['a', 'b', 'c', 'd']

# %%
item.remove("d")
item
# Out:
# ['a', 'b', 'c']

# %%
item
# Out:
# ['a', 'b', 'c']

# %%
exp = [30,12000,34455,890]
exp.sort(reverse=True)
exp
# Out:
# [34455, 12000, 890, 30]

# %%
exp = [30,12000,34455,890]
exp.sort()
exp
# Out:
# [30, 890, 12000, 34455]

# %%
item_1 = ["bread", "pasta","fruits","vadapav"]
item_2 = ["soap","shampoo"]
items =  item_1 + item_2
items
# Out:
# ['bread', 'pasta', 'fruits', 'vadapav', 'soap', 'shampoo']

# %%
len (items)
# Out:
# 6

# %%
print(items)
# Out:
# ['bread', 'pasta', 'fruits', 'vadapav', 'soap', 'shampoo']

# %%
'rice' in items
# Out:
# False

# %%
 len(items)
# Out:
# 6

# %%
items[1] = 'sandwiches'
items
# Out:
# ['bread', 'sandwiches', 'fruits', 'vadapav', 'soap', 'shampoo']

# %%
items[:6]
# Out:
# ['bread', 'sandwiches', 'fruits', 'vadapav', 'soap', 'shampoo']

# %%
items[3] = 'almonds'
items
# Out:
# ['bread', 'sandwiches', 'fruits', 'almonds', 'soap', 'shampoo']

# %%
food_items =  []

# %%
list_2 = ["python","java",99,90]
list_2
type(list_2)
# Out:
# list

# %%
t = ("python","java",99,90)
t
type(t)
# Out:
# tuple

# %%
ip = {'names': ["varad","vai"],
      'age':[56,77]
}

# %%
type(ip)
# Out:
# dict

# %%
bi1,bi2 = 15,20

print(bi1&bi2)
print(bi1 | bi2)
# Out:
# 4
# 31

# %%
entity = ["doc","patient","Department","appointment"]
print(entity)
entity[0]
entity[:2]
entity.append("names")
print(entity)
entity.remove("names")
len(entity)
# Out:
# ['doc', 'patient', 'Department', 'appointment']
# ['doc', 'patient', 'Department', 'appointment', 'names']
# 4

# %%
hi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 hi
#
# NameError: name 'hi' is not defined
