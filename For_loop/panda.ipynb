# %%
# write your code here
product_names = ["Apples", "Bananas", "Oranges", "Pears", "Grapes"]
stock_levels = [20, 50, 15, 5, 8]

minimum_stock = 10  # Minimum stock before reordering

reorder_list = []

for i in range(len(product_names)):
    if stock_levels[i] < minimum_stock:
        reorder_list.append(product_names[i])

print("Items to Reorder:")
for product in reorder_list:
    print(f"- {product}")
# Out:
# Items to Reorder:
# - Pears
# - Grapes

# %%
exp = [1200,1300,1400,1500]

total_exp = 0
for expense in exp:
    total_exp += expense

print(total_exp)
# Out:
# 5400

# %%
exp = [1200,1300,1400,1500]

total_exp = 0
for i in range(len(exp)):
    expense = exp[i]
    total_exp += expense
    print(f" Month {i+1}, Expene: {expense}")
print(f"Total Expenses of all months- {total_exp}")
# Out:
#  Month 1, Expene: 1200
#  Month 2, Expene: 1300
#  Month 3, Expene: 1400
#  Month 4, Expene: 1500
# Total Expenses of all months- 5400

# %%
#Break in for lo
monthly_sales = [42,88,90,67,69,43,56,23,24,34,35]
months = ["jan","feb","mar","arp","may","jun","jul","aug","sep","oct","nov"]

threslod  = 45

for sales_amount,months in zip(monthly_sales,months):
    if sales_amount <= threslod:
        print(f"{sales_amount} is less than {threslod} in {months}")
    else:
        print(f"{sales_amount} is greater than {threslod} in {months}")
# Out:
# 42 is less than 45 in jan
# 88 is greater than 45 in feb
# 90 is greater than 45 in mar
# 67 is greater than 45 in arp
# 69 is greater than 45 in may
# 43 is less than 45 in jun
# 56 is greater than 45 in jul
# 23 is less than 45 in aug
# 24 is less than 45 in sep
# 34 is less than 45 in oct
# 35 is less than 45 in nov

# %%
#pandas
dict =
