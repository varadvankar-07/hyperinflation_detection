# %%
import numpy as np

# %%
charr = np.array([1,2,3,33,3])
charr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 charr = np.array([1,2,3,33,3])
#       2 charr
#
# NameError: name 'np' is not defined

# %%
Student = {
    "name": "varad",
    "age":24,
     "marks": 78}
Student
# Out:
# {'name': 'varad', 'age': 24, 'marks': 78}

# %%
print("Name:", Student["name"])
# Out:
# Name: varad

# %%
Student["city"] = "Pune"
Student
# Out:
# {'name': 'varad', 'age': 24, 'marks': 78, 'city': 'Pune'}

# %%
#update
Student["marks"] = 90

# %%
Student.pop("age")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Student.pop("age")
#
# KeyError: 'age'

# %%
Student
# Out:
# {'name': 'varad', 'marks': 90, 'city': 'Pune'}

# %%
#taking input from user
Student = {}
name = input("Enter your name: ")
age = int(input("Enter your age: "))
marks = float(input("Enter your marks: "))
Student["name"] = name
Student["age"] = age
Student["marks"] = marks
Student
# Out:
# {'name': 'Varad', 'age': 22, 'marks': 32.0}

# %%
#craete a dict Students marks AND FIMDS THE WHICH STUDENT HAVE HIGHEST MARKS

# %%
info = {"name": {"Varad", "Ram", "Tapan"},
        "div": {2,1,1},
        "age": {18, 19,20},
        "marks": {56,67,78}}
print(info)
# Out:
# {'name': {'Varad', 'Ram', 'Tapan'}, 'div': {1, 2}, 'age': {18, 19, 20}, 'marks': {56, 67, 78}}

# %%
highest = max(info["marks"])
print(highest)
# Out:
# 78

# %%
data = [1, 2, 2, 3, 3, 3, 4, 'a', 'a', 'b']
freq = {}
for item in data:
        if item in freq:
            freq[item] += 1
        else:
            freq[item] = 1

result = (freq)
print(result)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 1, 'a': 2, 'b': 1}

# %%
def binarySearch(arr, x):
    low = 0
    high = len(arr) - 1
    while low <= high:

        mid = low + (high - low) // 2

        # Check if x is present at mid
        if arr[mid] == x:
            return mid

        # If x is greater, ignore left half
        elif arr[mid] < x:
            low = mid + 1

        # If x is smaller, ignore right half
        else:
            high = mid - 1

    # If we reach here, then the element
    # was not present
    return -1

if __name__ == '__main__':
    arr = [2, 3, 4, 10, 40]
    x = 3

    result = binarySearch(arr, x)
    if result != -1:
        print("Element is present at index", result)
    else:
        print("Element is not present in array")
# Out:
# Element is present at index 1

# %%
number = [99,88,77]
X = 88
low  = 0
high = len(number)-1
while low <= high:
    mid = (low + high) // 2
    if number[mid] == X:
        print("Element is present at index", mid)
# Out:
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# Element is present at index 1
# ...
