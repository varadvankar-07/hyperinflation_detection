# %%
from win32cryptcon import szOID_PKCS_7_DATA

can = "soda"
can
# Out:
# 'soda'

# %%
can = "beans"
can
# Out:
# 'beans'

# %%
type(pizza)
# Out:
# int

# %%
pizza=100
pizza
# Out:
# 100

# %%
samosa=50
pav_vada=20.5
samosa
# Out:
# 50

# %%
total = samosa + pav_vada
total
# Out:
# 70.5

# %%
total > 100
# Out:
# True

# %%
type(total)
# Out:
# float

# %%
above_thresold = total > 200
above_thresold
# Out:
# False

# %%
can  = "food"
can
# Out:
# 'food'

# %%
can
# Out:
# 'food'

# %%
type(can)
# Out:
# str

# %%
food = "jalebi"
food
# Out:
# 'jalebi'

# %%
bar=food
bar
# Out:
# 'jalebi'

# %%
id(bar)
# Out:
# 2315417185728

# %%
id(food)
# Out:
# 2315436767920

# %%
bar = "samosa"
bar
# Out:
# 'samosa'

# %%
id(bar)
# Out:
# 2315417185728

# %%
def = "hello"
# Out:
#   Cell In[58], line 1
#     def = "hello"
#         ^
# SyntaxError: invalid syntax

# %%
name_person='varad'
name_person
# Out:
# 'varad'

# %%
base = 20.5
height = 20
area = 1/2 * base * height 
area
# Out:
# 205.0

# %%
type(area)
# Out:
# float

# %%
foo = "jalebi"
foo
# Out:
# 'jalebi'

# %%
bar=foo 
bar
# Out:
# 'jalebi'

# %%
id(bar)
# Out:
# 2315436767920

# %%
can = "soda"
can
# Out:
# 'soda'

# %%
can
# Out:
# 'soda'

# %%
type(can)
# Out:
# str

# %%
pav_vada = 20.5
pizaa = 100
ice_cream = 100
total = pizaa + pav_vada + ice_cream
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
total > 100
# Out:
# True

# %%
above_thresold = total > 100
above_thresold
# Out:
# True

# %%
can
# Out:
# 'soda'

# %%
can = 6.66

# %%
type(can)
# Out:
# float

# %%
foo = "jalebi"
foo
# Out:
# 'jalebi'

# %%
bar = foo
bar
# Out:
# 'jalebi'

# %%
id(foo)
# Out:
# 3050730892544

# %%
id(bar)
# Out:
# 3050730892544

# %%
bar = "samosa"
bar
# Out:
# 'samosa'

# %%
foo
# Out:
# 'jalebi'

# %%
True = 4
# Out:
#   Cell In[32], line 1
#     True = 4
#     ^
# SyntaxError: cannot assign to True
