# %%
from python_lab import choice

from Lab_exp import digit


#Runs scored: 60 Balls faced: 40 Calculation: ((60/40)*100=150) Strike Rate:150
def st(runs,balls):             #function def
    ST= (runs/balls)*100
    print(f"{ST:.2f}")          #retrun function

st(100,50)
# Out:
# 200.00

# %%
st(12,20) #calling function
# Out:
# 60.00

# %%
st(77,67)
# Out:
# 114.93

# %%
st(100,110)
# Out:
# 90.91

# %%
avg_virat = 9230/190
print(f"{avg_virat:.2f}")
# Out:
# 48.58

# %%
avg = 15934/259
print(f"{avg:.2f}")
# Out:
# 61.52

# %%
N1 = float(input("Enter the first number: "))
N2 = float(input("Enter the second number: "))

print("Choose the operation that u have to perform :")
print("1. Add")
print("2. Sub")
print("3. Mul")
print("4. Div")

choice = input("Enter your choice: 1,2,3,4")

if choice == "1":
    N = N1 + N2
    print(f"Answer {N:.2f}")
elif choice == "2":
    N = N1 - N2
    print(f"Answer {N:.2f}")
elif choice == "3":
    N = N1 * N2
    print(f"Answer {N:.2f}")
elif choice == "4":
    N = N1 / N2
    print(f"Answer {N:.2f}")
else :
    print("Invalid choice")
# Out:
# Choose the operation that u have to perform :
# 1. Add
# 2. Sub
# 3. Mul
# 4. Div
# Answer 990.00

# %%
for i in range(1,11):
    if i%2 == 0:
        print(i**2, end=" ")
    else:
        print(i**3, end=" ")
# Out:
# 1 4 27 16 125 36 343 64 729 100

# %%
n = 90
fact = 1
i = 1
while i<=n:
  fact = fact*i
  i=i+1
print(fact)
# Out:
# 1485715964481761497309522733620825737885569961284688766942216863704985393094065876545992131370884059645617234469978112000000000000000000000

# %%
number = 4
fact = 1
i = 1
while i<=number:
# Out:
# 16

# %%
n = 4
fact = 1
i=1
while i<=n:
    fact=fact*i
    i=i+1
print(fact)
# Out:
# 24

# %%
def reverse(number):
    rev = 0
    while number != 0 :
        digit = number % 10
        rev = rev * 10 +digit
        number = number // 10
    return rev
reverse(123)
# Out:
# 321

# %%
def

# %%
def reverse(num):
    rev = 0
    while num!=0:
        digit = num % 10
        rev = rev * 10 + digit
        num = num//10
    return rev
reverse(130008769876986)
# Out:
# 689678967800031

# %%
reverse(6764345678)
# Out:
# 8765434676

# %%
def GCD(a,b):
    if b == 0:
        return a
    else:
        return GCD(b, a % b)
print(GCD(36,60))
# Out:
# 12

# %%
1000**2
# Out:
# 1000000
