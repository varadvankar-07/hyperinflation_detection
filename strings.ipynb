# %%
from variable import samosa

first = 'varad'
last = 'vankar'

# %%
type(first)
# Out:
# str

# %%
name = first + ' ' + last
name
# Out:
# 'varad vankar'

# %%
name = f"{first} {last}"
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name = f"{first}       {last}"
#       2 name
#
# NameError: name 'first' is not defined

# %%
age = 30
info = f"{first} {last} is {age} years old."
info
# Out:
# 'varad vankar is 30 years old.'

# %%
age = 18
info = f" {first} {last} is {age} years old"
info
# Out:
# ' varad vankar is 18 years old'

# %%
ff = "varad"
gg = "vankar"
res = ff + " " + gg
res
# Out:
# 'varad vankar'

# %%
name[0:]
# Out:
# 'varad vankar'

# %%
man = "ram mohan"

# %%
man[:-1]
# Out:
# 'ram moha'

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
man[0:]
# Out:
# 'ram mohan'

# %%
len(man)
# Out:
# 9

# %%
name[-2]
# Out:
# 'a'

# %%
len(name)
# Out:
# 12

# %%
recipe = '''veg biryani with saffron, cardammon and cloves'''
print(recipe)
# Out:
# veg biryani with saffron, cardammon and cloves

# %%
spice =  "saffron"
spice in recipe
# Out:
# True

# %%
s = "varad was charged 100$ for lab test"
s
# Out:
# 'varad was charged 100$ for lab test'

# %%
s= s.replace("100", "10")

# %%
s
# Out:
# 'varad was charged 10$ for lab test'

# %%
s.upper()
# Out:
# 'VARAD WAS CHARGED 10$ FOR LAB TEST'

# %%
text = "my age is "
age = 18
text + str(age)
# Out:
# 'my age is 18'

# %%
T = "AAPL|IPL|NVID|GOOLGE"
T.split("|")
# Out:
# ['AAPL', 'IPL', 'NVID', 'GOOLGE']

# %%
T.split("IPL")
# Out:
# ['AAPL|', '|NVID|GOOLGE']

# %% [markdown]
# 5 aug 2025

# %%
first = "varad"
last = "vankar"

# %%
name = first + " " + last
name                     #for writing name in form of varad vankar the above code is to used.
# Out:
# 'varad vankar'

# %%
age = 18
info = f" {first} {last} is {age} year old "
info
# Out:
# ' varad vankar is 18 year old '

# %%
name[2]
# Out:
# 'r'

# %%
name[0:5]
# Out:
# 'varad'

# %%
name[6:]
# Out:
# 'vankar'

# %%
name[-6]
# Out:
# 'v'

# %%
len(name)
# Out:
# 12

# %%
food = '''veg biryani with saffron, cardammon and cloves'''
food
# Out:
# 'veg biryani with saffron, cardammon and cloves'

# %%
spice = "cardammon"
spice in food
# Out:
# True

# %%
"milk" in food
# Out:
# False

# %%
food.find('cardammon')#it will find out the index
# Out:
# 26

# %%
s = "varad was charged 100$ for lab test"
s
# Out:
# 'varad was charged 100$ for lab test'

# %%
k=s.append(288)
k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 k=s.append(288)
#       2 k
#
# NameError: name 's' is not defined

# %%
s = s.replace("100", "10")
s
# Out:
# 'varad was charged 10$ for lab test'

# %%
s.upper()
# Out:
# 'VARAD WAS CHARGED 10$ FOR LAB TEST'

# %%
text = "my age is "
age = 18
text + str(age)
# Out:
# 'my age is 18'

# %%
tt = "AAPL|IPL|NVID|GOOLGE"
tt.split("|")
# Out:
# ['AAPL', 'IPL', 'NVID', 'GOOLGE']

# %%
tt.find("IPL")
# Out:
# 5

# %%
data = " varad was charged  100$ for     lab test"
data
# Out:
# ' varad was charged  100$ for     lab test'

# %%
data.strip()
# Out:
# 'varad was charged  100$ for     lab test'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
fu = "apple, banna"
veg = "potato, tamato"
info = f" I eat {veg} and {fu} daily"
info
# Out:
# ' I eat potato, tamato and apple, banna daily'

# %%
s = "The Himalayas are one of the youngest mountain ranges on the planet"
s
# Out:
# 'The Himalayas are one of the youngest mountain ranges on the planet'

# %%
s[0:13]
# Out:
# 'The Himalayas'

# %%
s[-29:-15]
# Out:
# 'mountain range'

# %%
info = (f"{s[0:13]} {s[-14:]}")
#print(f"{string[0:13]} {string[-14:]}")
info
# Out:
# 'The Himalayas  on the planet'

# %%
b = "There are 9 planets in the solar system"
b
# Out:
# 'There are 9 planets in the solar system'

# %%
b = b.replace('8 planets', '9 planet')
print(b)
# Out:
# There are 9 planets in the solar system

# %%
A = "There are 9 planets in the solar system"
B = A.replace('9 planets', '8 planets')
print(B)
# Out:
# There are 8 planets in the solar system

# %%
AL_ON_COO=45
AL_ON_COO
# Out:
# 45

# %%
AL123=50
AL123
# Out:
# 50

# %%
123AL=70
123AL
# Out:
#   Cell In[96], line 1
#     123AL=70
#       ^
# SyntaxError: invalid decimal literal

# %%
5+4*3
# Out:
# 17

# %%
S="12345a"
print(s.isdigit())
# Out:
# False

# %%
-9%2
# Out:
# 1

# %%
A = "varad vankar"
A
# Out:
# 'varad vankar'

# %%
len(A)
# Out:
# 12

# %%
A[0:12] # we can also write A[0:]
# Out:
# 'varad vankar'

# %%
A[-12:]
# Out:
# 'varad vankar'

# %%
C = "ram mohon roy"
age = 35

# %%
info = f"{C} is {age} years old"
info
# Out:
# 'ram mohon roy is 35 years old'

# %%
len(C)
# Out:
# 13

# %%
C[0:]
# Out:
# 'ram mohon roy'

# %%
C[:-1]
# Out:
# 'ram mohon ro'

# %%
oppp = '''He said "opps" '''

# %%
text = "programming"
text
# Out:
# 'programming'

# %%
len(text)
# Out:
# 18

# %%
text[0:]
# Out:
# 'programming'

# %%
#Slice with step
text[0:10:2]
# Out:
# 'pormi'

# %%
text =  text.replace("programming", "python programming")
text
# Out:
# 'python programming'

# %%
text[0:]
# Out:
# 'python programming'

# %%
text[::-1]
# Out:
# 'gnimmargorp nohtyp'

# %%
n = 7653
rev =0
while n > 0:
    rev = 10*rev + n%10
    n = n // 10
print(rev)
# Out:
# 3567

# %%
m = "7276"
m
# Out:
# '7276'

# %%
m[::-1]
# Out:
# '6727'

# %%
A = str(input("enter string"))
print(A[::-1])
# Out:
# 23456789

# %%
x = 2
X = x**x
print(X)
# Out:
# 4

# %%
A = input("Enter a number: ")
reversed_num = int(A[::-1])
print(reversed_num)
type(reversed_num)
# Out:
# 9879
# int

# %%
def greeting(name):
    message = "Hello " + name
    return message
result = greeting("Ram")
print(result)
# Out:
# Hello Ram

# %%
kk = "hi"
print(kk * 1)
# Out:
# hi

# %%
ki = "python programming"
len(ki)
# Out:
# 18

# %%
ki[:18]
# Out:
# 'python programming'

# %%
ki[::-1]
# Out:
# 'gnimmargorp nohtyp'

# %%
ki[7:18:2]
# Out:
# 'pormig'

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
print("Concatenated string:", str1 + " " + str2)
# Out:
# Concatenated string: varad vankar

# %%
text = "Python"
for ch in text:
    print(ch)
# Out:
# P
# y
# t
# h
# o
# n

# %%
text = "PuneUniversity"
print(text[3:10])   # Output: eUniver
# Out:
# eUniver

# %%
text = "HelloWorld"
print(text[::2])    # Output: HloWrd
# Out:
# Hlool

# %%
m1 = int(input("Enter marks in subject 1: "))
m2 = int(input("Enter marks in subject 2: "))
m3 = int(input("Enter marks in subject 3: "))

total = m1 + m2 + m3
percentage = total / 3

print(f"Total = {total}, Percentage = {percentage:.2f}%")
# Out:
# Total = 244, Percentage = 81.33%
